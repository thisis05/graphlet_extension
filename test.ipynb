# %%
import subprocess
import re
import os
import numpy as np

def modify_first_line(file_path):
    """파일의 첫 번째 줄을 '노드 수 엣지 수' 형식으로 변경"""
    with open(file_path, 'r') as file:
        lines = file.readlines()

    # 첫 번째 줄을 "노드 수 엣지 수" 형식으로 변경
    node_edge_info = lines[1].strip().split()
    node_count = node_edge_info[0]
    edge_count = node_edge_info[2]
    lines[0] = f"{node_count} {edge_count}\n"

    with open(file_path, 'w') as file:
        file.writelines(lines)

def run_subgraph_counts(file_path):
    """subgraph_counts.py를 실행하고 결과를 반환"""
    command = ['python', './escape/wrappers/subgraph_counts.py', file_path, '5', '-i']
    result = subprocess.run(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
    return result.stdout

def parse_output(output):
    """subgraph_counts.py의 출력을 파싱하여 매핑된 패턴과 값을 딕셔너리로 반환"""
    mapping = {
        "4-1": "4-clique",
        "4-2": "Diamond",
        "4-3": "Tailed triangle",
        "4-4": "4-cycle",
        "4-5": "3-star",
        "4-6": "3-path",
        "5-1": "4-star",
        "5-2": "Prong",
        "5-3": "4-path",
        "5-4": "Forktailed-tri",
        "5-5": "Lontailed-tri",
        "5-6": "Doubletailed-tri",
        "5-7": "Tailed-4-cycle",
        "5-8": "5-cycle",
        "5-9": "Hourglass",
        "5-10": "Cobra",
        "5-11": "Stingray",
        "5-12": "Hatted-4-cycle",
        "5-13": "3-wedge-col",
        "5-14": "3-tri-collision",
        "5-15": "Tailed-4-clique",
        "5-16": "Triangle-strip",
        "5-17": "Diamond-wed-col",
        "5-18": "4-wheel",
        "5-19": "Hatted-4-clique",
        "5-20": "Almost-5-clique",
        "5-21": "5-clique"
    }
    
    reverse_mapping = {v: k for k, v in mapping.items()}
    pattern_counts = {}

    for line in output.split("\n"):
        match = re.match(r"(\w[\w\s\-]*)\s+(\d+)\s+(\d+)\s+([\d\.]+)", line)
        if match:
            pattern_name = match.group(1).strip()
            count = float(match.group(3).strip())
            if pattern_name in reverse_mapping:
                mapped_name = reverse_mapping[pattern_name]
                if mapped_name not in pattern_counts:
                    pattern_counts[mapped_name] = []
                pattern_counts[mapped_name].append(count)

    return pattern_counts

def average_counts(pattern_counts):
    """각 패턴의 값을 평균내어 반환"""
    averaged_counts = {pattern: np.mean(counts) for pattern, counts in pattern_counts.items()}
    return averaged_counts

def main():
    base_file_path = './datasets/email-univ.mtx'
    random_folder_path = './datasets/email-univ_random'

    # Base 파일 처리
    modify_first_line(base_file_path)
    output = run_subgraph_counts(base_file_path)
    base_counts = parse_output(output)

    # Base 파일 결과 출력
    print("Base File Results:")
    print("{")
    for key in sorted(base_counts.keys()):
        print(f'    "{key}" : {base_counts[key][0]:.2f},')  # base file has single value for each pattern
    print("}")

    # Random graph files 처리
    random_counts = {}
    for i in range(1, 11):
        file_path = os.path.join(random_folder_path, f'email-univ_r{i}.mtx')
        modify_first_line(file_path)
        output = run_subgraph_counts(file_path)
        counts = parse_output(output)

        # 각 패턴의 값을 합산
        for pattern, count_list in counts.items():
            if pattern not in random_counts:
                random_counts[pattern] = []
            random_counts[pattern].extend(count_list)

    # 평균 계산
    averaged_counts = average_counts(random_counts)

    # Random graph 파일 결과 출력
    print("Random Graphs Results (Averaged):")
    print("{")
    for key in sorted(averaged_counts.keys()):
        print(f'    "{key}" : {averaged_counts[key]:.2f},')
    print("}")

if __name__ == "__main__":
    main()
# Out:
# Base File Raw Output:
#  Running command: ./escape/exe/count_five ./datasets/email-univ.mtx
# Loading graph
# Converting to CSR
# Relabeling graph
# Creating DAG
# Counting 3-vertex
# Counting 4-vertex
# Getting easy four vertex patterns
# Getting four cycles
# Getting four cliques
# Counting 5-vertex
# Getting all triangles
# Also getting reverse triangle info
# Counting trees
# Counting triangle based patterns
# Counting 4-cycle and 4-clique based patterns
# Counting five cycles
# Counting collision patterns
# Counting almost cliques
# ==============
# Basic size
# ==============
# Vertices	 1133
# Edges		 5451
# ==============
# 3 vertex patterns
# ==============
# Ind set		 241761806 235689480 0.97
# Only edge	 6163384 5986609 0.97
# Wedge		 96402 80373 0.83
# Triangle	 5343 5343 1.00
# ==============
# 4 vertex patterns
# ==============
# Ind set		 68297710195 64930817277 0.95
# Only edge	 3482312242 3259425872 0.94
# Matching	 14749398 13349798 0.91
# Only wedge	 108934260 86446054 0.79
# Only triangle	 6037590 5765708 0.95
# 3-star		 817936 546054 0.67
# 3-path		 1755241 1105885 0.63
# Tailed triangle	 340646 216794 0.64
# 4-cycle		 43589 12626 0.29
# Diamond		 41220 20706 0.50
# 4-clique	 3419 3419 1.00
# ==============
# 5 vertex patterns
# ==============
# Ind set		 15421622962031 14182911015152 0.92
# Only edge	 1310510173927 1172830015048 0.89
# Matching	 16652070765 14250699592 0.86
# Only wedge	 61493389770 46098199985 0.75
# Only triangle	 3408219555 3084721178 0.91
# Only 3-star	 923449744 576021957 0.62
# Only 3-path	 1981667089 1165506560 0.59
# Only Tailed tri	 384589334 228906818 0.60
# Only 4-cycle	 49211981 13277437 0.27
# Only Diamond	 46537380 21920918 0.47
# Only 4-clique	 3860051 3656283 0.95
# Wedge+edge	 519169576 365061503 0.70
# Triangle+edge	 28760003 24637222 0.86
# 4-star		 6550476 3378919 0.52
# Prong		 45381451 21349439 0.47
# 4-path		 32399569 14321797 0.44
# Forktailed-tri	 4785389 2072430 0.43
# Lontailed-tri	 6279568 2749259 0.44
# Doubletailed-tri 7576837 2917304 0.39
# Tailed-4-cycle	 4016691 791982 0.20
# 5-cycle		 458628 76281 0.17
# Hourglass	 346905 117042 0.34
# Cobra		 1721771 496856 0.29
# Stingray	 1973577 608154 0.31
# Hatted-4-cycle	 885415 117919 0.13
# 3-wedge-col	 136461 10453 0.08
# 3-tri-collision	 94192 20996 0.22
# Tailed-4-clique	 294021 147629 0.50
# Triangle-strip	 477676 84392 0.18
# Diamond-wed-col	 189376 15680 0.08
# 4-wheel		 55868 4697 0.08
# Hatted-4-clique	 134682 32340 0.24
# Almost-5-clique	 27372 6742 0.25
# 5-clique	 2063 2063 1.00
#
# Base File Results:
# {
#     "4-1" : 3419.00,
#     "4-2" : 20706.00,
#     "4-3" : 216794.00,
#     "4-4" : 12626.00,
#     "4-5" : 546054.00,
#     "4-6" : 1105885.00,
#     "5-1" : 3378919.00,
#     "5-10" : 496856.00,
#     "5-11" : 608154.00,
#     "5-12" : 117919.00,
#     "5-13" : 10453.00,
#     "5-14" : 20996.00,
#     "5-15" : 147629.00,
#     "5-16" : 84392.00,
#     "5-17" : 15680.00,
#     "5-18" : 4697.00,
#     "5-19" : 32340.00,
#     "5-2" : 21349439.00,
#     "5-20" : 6742.00,
#     "5-21" : 2063.00,
#     "5-3" : 14321797.00,
#     "5-4" : 2072430.00,
#     "5-5" : 2749259.00,
#     "5-6" : 2917304.00,
#     "5-7" : 791982.00,
#     "5-8" : 76281.00,
#     "5-9" : 117042.00,
# }
# Random Graph File r1 Raw Output:
#  Running command: ./escape/exe/count_five ./datasets/email-univ_random/email-univ_r1.mtx
# Loading graph
# Converting to CSR
# Relabeling graph
# Creating DAG
# Counting 3-vertex
# Counting 4-vertex
# Getting easy four vertex patterns
# Getting four cycles
# Getting four cliques
# Counting 5-vertex
# Getting all triangles
# Also getting reverse triangle info
# Counting trees
# Counting triangle based patterns
# Counting 4-cycle and 4-clique based patterns
# Counting five cycles
# Counting collision patterns
# Counting almost cliques
# ==============
# Basic size
# ==============
# Vertices	 1133
# Edges		 5367
# ==============
# 3 vertex patterns
# ==============
# Ind set		 241761806 235784809 0.98
# Only edge	 6068380 5886400 0.97
# Wedge		 92172 89808 0.97
# Triangle	 788 788 1.00
# ==============
# 4 vertex patterns
# ==============
# Ind set		 68297710195 64984385713 0.95
# Only edge	 3428634982 3201091844 0.93
# Matching	 14299440 12806161 0.90
# Only wedge	 104154360 96413075 0.93
# Only triangle	 890440 835607 0.94
# 3-star		 749948 695115 0.93
# 3-path		 1569324 1419172 0.90
# Tailed triangle	 56791 52915 0.93
# 4-cycle		 10611 9642 0.91
# Diamond		 999 939 0.94
# 4-clique	 10 10 1.00
# ==============
# 5 vertex patterns
# ==============
# Ind set		 15421622962031 14202787638273 0.92
# Only edge	 1290309631747 1150685824789 0.89
# Matching	 16144068183 13634734794 0.84
# Only wedge	 58795136220 51325097138 0.87
# Only triangle	 502653380 439467461 0.87
# Only 3-star	 846691292 731635298 0.86
# Only 3-path	 1771766796 1492446579 0.84
# Only Tailed tri	 64117039 55059645 0.86
# Only 4-cycle	 11979819 10021965 0.84
# Only Diamond	 1127871 967138 0.86
# Only 4-clique	 11290 10269 0.91
# Wedge+edge	 488973666 395769107 0.81
# Triangle+edge	 4168859 3312482 0.79
# 4-star		 5679037 4897580 0.86
# Prong		 37939806 31240238 0.82
# 4-path		 26565432 21171446 0.80
# Forktailed-tri	 846029 720369 0.85
# Lontailed-tri	 953258 765656 0.80
# Doubletailed-tri 1343358 1119125 0.83
# Tailed-4-cycle	 1012467 818217 0.81
# 5-cycle		 142326 110321 0.78
# Hourglass	 10429 8636 0.83
# Cobra		 47004 38800 0.83
# Stingray	 57772 49110 0.85
# Hatted-4-cycle	 35466 28770 0.81
# 3-wedge-col	 6263 5150 0.82
# 3-tri-collision	 365 307 0.84
# Tailed-4-clique	 1080 964 0.89
# Triangle-strip	 1967 1625 0.83
# Diamond-wed-col	 863 695 0.81
# 4-wheel		 29 26 0.90
# Hatted-4-clique	 61 55 0.90
# Almost-5-clique	 1 1 1.00
# 5-clique	 0 0 -
#
# Random Graph File r2 Raw Output:
#  Running command: ./escape/exe/count_five ./datasets/email-univ_random/email-univ_r2.mtx
# Loading graph
# Converting to CSR
# Relabeling graph
# Creating DAG
# Counting 3-vertex
# Counting 4-vertex
# Getting easy four vertex patterns
# Getting four cycles
# Getting four cliques
# Counting 5-vertex
# Getting all triangles
# Also getting reverse triangle info
# Counting trees
# Counting triangle based patterns
# Counting 4-cycle and 4-clique based patterns
# Counting five cycles
# Counting collision patterns
# Counting almost cliques
# ==============
# Basic size
# ==============
# Vertices	 1133
# Edges		 5373
# ==============
# 3 vertex patterns
# ==============
# Ind set		 241761806 235778045 0.98
# Only edge	 6075166 5893159 0.97
# Wedge		 92211 89796 0.97
# Triangle	 805 805 1.00
# ==============
# 4 vertex patterns
# ==============
# Ind set		 68297710195 64980597399 0.95
# Only edge	 3432469072 3204862389 0.93
# Matching	 14331609 12825888 0.89
# Only wedge	 104198430 96385468 0.93
# Only triangle	 909650 852748 0.94
# 3-star		 748470 691568 0.92
# 3-path		 1584610 1428966 0.90
# Tailed triangle	 59058 54790 0.93
# 4-cycle		 10999 9932 0.90
# Diamond		 1100 1034 0.94
# 4-clique	 11 11 1.00
# ==============
# 5 vertex patterns
# ==============
# Ind set		 15421622962031 14201382548691 0.92
# Only edge	 1291752527617 1152073041557 0.89
# Matching	 16180386984 13657712573 0.84
# Only wedge	 58820013735 51303210106 0.87
# Only triangle	 513497425 448039252 0.87
# Only 3-star	 845022630 727580923 0.86
# Only 3-path	 1789024690 1502428866 0.84
# Only Tailed tri	 66676482 56933259 0.85
# Only 4-cycle	 12417871 10315123 0.83
# Only Diamond	 1241900 1063171 0.86
# Only 4-clique	 12419 11295 0.91
# Wedge+edge	 489709919 395188096 0.81
# Triangle+edge	 4262584 3362904 0.79
# 4-star		 5666034 4846856 0.86
# Prong		 38442126 31395434 0.82
# 4-path		 27105837 21441561 0.79
# Forktailed-tri	 891867 750570 0.84
# Lontailed-tri	 1007094 799482 0.79
# Doubletailed-tri 1431222 1180496 0.82
# Tailed-4-cycle	 1063844 848337 0.80
# 5-cycle		 150015 114595 0.76
# Hourglass	 11530 9453 0.82
# Cobra		 52323 42855 0.82
# Stingray	 65402 55230 0.84
# Hatted-4-cycle	 39559 31521 0.80
# 3-wedge-col	 6895 5483 0.80
# 3-tri-collision	 475 409 0.86
# Tailed-4-clique	 1192 1060 0.89
# Triangle-strip	 2269 1897 0.84
# Diamond-wed-col	 1061 887 0.84
# 4-wheel		 30 24 0.80
# Hatted-4-clique	 72 60 0.83
# Almost-5-clique	 2 2 1.00
# 5-clique	 0 0 -
#
# Random Graph File r3 Raw Output:
#  Running command: ./escape/exe/count_five ./datasets/email-univ_random/email-univ_r3.mtx
# Loading graph
# Converting to CSR
# Relabeling graph
# Creating DAG
# Counting 3-vertex
# Counting 4-vertex
# Getting easy four vertex patterns
# Getting four cycles
# Getting four cliques
# Counting 5-vertex
# Getting all triangles
# Also getting reverse triangle info
# Counting trees
# Counting triangle based patterns
# Counting 4-cycle and 4-clique based patterns
# Counting five cycles
# Counting collision patterns
# Counting almost cliques
# ==============
# Basic size
# ==============
# Vertices	 1133
# Edges		 5366
# ==============
# 3 vertex patterns
# ==============
# Ind set		 241761806 235785402 0.98
# Only edge	 6067249 5886413 0.97
# Wedge		 91702 89134 0.97
# Triangle	 856 856 1.00
# ==============
# 4 vertex patterns
# ==============
# Ind set		 68297710195 64984424726 0.95
# Only edge	 3427995967 3201709679 0.93
# Matching	 14294545 12800315 0.90
# Only wedge	 103623260 95711985 0.92
# Only triangle	 967280 905734 0.94
# 3-star		 736121 674575 0.92
# 3-path		 1577902 1413308 0.90
# Tailed triangle	 64344 58844 0.91
# 4-cycle		 11075 9700 0.88
# Diamond		 1447 1303 0.90
# 4-clique	 24 24 1.00
# ==============
# 5 vertex patterns
# ==============
# Ind set		 15421622962031 14202696800096 0.92
# Only edge	 1290069149102 1151126099641 0.89
# Matching	 16138542292 13634739935 0.84
# Only wedge	 58495330270 50964492575 0.87
# Only triangle	 546029560 475363364 0.87
# Only 3-star	 831080609 710275039 0.85
# Only 3-path	 1781451358 1486657754 0.83
# Only Tailed tri	 72644376 61075105 0.84
# Only 4-cycle	 12503675 10076365 0.81
# Only Diamond	 1633663 1333979 0.82
# Only 4-clique	 27096 24131 0.89
# Wedge+edge	 486385240 392077431 0.81
# Triangle+edge	 4525100 3548093 0.78
# 4-star		 5431983 4548698 0.84
# Prong		 38183037 30632949 0.80
# 4-path		 27118721 21154053 0.78
# Forktailed-tri	 981402 793534 0.81
# Lontailed-tri	 1114807 852436 0.76
# Doubletailed-tri 1629178 1296296 0.80
# Tailed-4-cycle	 1087684 822220 0.76
# 5-cycle		 153052 112730 0.74
# Hourglass	 14849 11057 0.74
# Cobra		 75229 56052 0.75
# Stingray	 92266 70933 0.77
# Hatted-4-cycle	 47218 34238 0.73
# 3-wedge-col	 7570 5412 0.71
# 3-tri-collision	 952 675 0.71
# Tailed-4-clique	 3251 2697 0.83
# Triangle-strip	 4502 3136 0.70
# Diamond-wed-col	 1630 1095 0.67
# 4-wheel		 78 51 0.65
# Hatted-4-clique	 304 250 0.82
# Almost-5-clique	 9 9 1.00
# 5-clique	 0 0 -
#
# Random Graph File r4 Raw Output:
#  Running command: ./escape/exe/count_five ./datasets/email-univ_random/email-univ_r4.mtx
# Loading graph
# Converting to CSR
# Relabeling graph
# Creating DAG
# Counting 3-vertex
# Counting 4-vertex
# Getting easy four vertex patterns
# Getting four cycles
# Getting four cliques
# Counting 5-vertex
# Getting all triangles
# Also getting reverse triangle info
# Counting trees
# Counting triangle based patterns
# Counting 4-cycle and 4-clique based patterns
# Counting five cycles
# Counting collision patterns
# Counting almost cliques
# ==============
# Basic size
# ==============
# Vertices	 1133
# Edges		 5353
# ==============
# 3 vertex patterns
# ==============
# Ind set		 241761806 235799857 0.98
# Only edge	 6052546 5872182 0.97
# Wedge		 91430 88934 0.97
# Triangle	 832 832 1.00
# ==============
# 4 vertex patterns
# ==============
# Ind set		 68297710195 64992394240 0.95
# Only edge	 3419688772 3194042132 0.93
# Matching	 14225170 12746046 0.90
# Only wedge	 103315900 95496888 0.92
# Only triangle	 940160 881730 0.94
# 3-star		 739288 680858 0.92
# 3-path		 1559212 1401326 0.90
# Tailed triangle	 60736 56156 0.92
# 4-cycle		 10833 9688 0.89
# Diamond		 1169 1121 0.96
# 4-clique	 8 8 1.00
# ==============
# 5 vertex patterns
# ==============
# Ind set		 15421622962031 14205601830455 0.92
# Only edge	 1286942874717 1148416024978 0.89
# Matching	 16060217353 13576390129 0.85
# Only wedge	 58321825550 50850390791 0.87
# Only triangle	 530720320 463456870 0.87
# Only 3-star	 834656152 716758876 0.86
# Only 3-path	 1760350348 1474091373 0.84
# Only Tailed tri	 68570944 58412345 0.85
# Only 4-cycle	 12230457 10067847 0.82
# Only Diamond	 1319801 1154645 0.87
# Only 4-clique	 9032 8217 0.91
# Wedge+edge	 483766001 390887265 0.81
# Triangle+edge	 4389216 3473808 0.79
# 4-star		 5575852 4746044 0.85
# Prong		 37613095 30540404 0.81
# 4-path		 26525670 20879396 0.79
# Forktailed-tri	 906364 757469 0.84
# Lontailed-tri	 1027476 810987 0.79
# Doubletailed-tri 1456898 1193913 0.82
# Tailed-4-cycle	 1042284 820291 0.79
# 5-cycle		 146605 110554 0.75
# Hourglass	 12289 9891 0.80
# Cobra		 54844 45567 0.83
# Stingray	 68638 58385 0.85
# Hatted-4-cycle	 40619 31751 0.78
# 3-wedge-col	 6853 5333 0.78
# 3-tri-collision	 531 473 0.89
# Tailed-4-clique	 873 757 0.87
# Triangle-strip	 2590 2206 0.85
# Diamond-wed-col	 1123 913 0.81
# 4-wheel		 38 38 1.00
# Hatted-4-clique	 58 58 1.00
# Almost-5-clique	 0 0 -
# 5-clique	 0 0 -
#
# Random Graph File r5 Raw Output:
#  Running command: ./escape/exe/count_five ./datasets/email-univ_random/email-univ_r5.mtx
# Loading graph
# Converting to CSR
# Relabeling graph
# Creating DAG
# Counting 3-vertex
# Counting 4-vertex
# Getting easy four vertex patterns
# Getting four cycles
# Getting four cliques
# Counting 5-vertex
# Getting all triangles
# Also getting reverse triangle info
# Counting trees
# Counting triangle based patterns
# Counting 4-cycle and 4-clique based patterns
# Counting five cycles
# Counting collision patterns
# Counting almost cliques
# ==============
# Basic size
# ==============
# Vertices	 1133
# Edges		 5373
# ==============
# 3 vertex patterns
# ==============
# Ind set		 241761806 235778125 0.98
# Only edge	 6075166 5893027 0.97
# Wedge		 92319 89820 0.97
# Triangle	 833 833 1.00
# ==============
# 4 vertex patterns
# ==============
# Ind set		 68297710195 64980674024 0.95
# Only edge	 3432469072 3204751313 0.93
# Matching	 14331501 12815703 0.89
# Only wedge	 104320470 96390910 0.92
# Only triangle	 941290 881357 0.94
# 3-star		 752111 692178 0.92
# 3-path		 1597924 1436112 0.90
# Tailed triangle	 62399 57519 0.92
# 4-cycle		 11103 9883 0.89
# Diamond		 1259 1181 0.94
# 4-clique	 13 13 1.00
# ==============
# 5 vertex patterns
# ==============
# Ind set		 15421622962031 14201418626955 0.92
# Only edge	 1291752527617 1152029173255 0.89
# Matching	 16180265052 13647485299 0.84
# Only wedge	 58888905315 51296923599 0.87
# Only triangle	 531358205 462573438 0.87
# Only 3-star	 849133319 727714943 0.86
# Only 3-path	 1804056196 1509306493 0.84
# Only Tailed tri	 70448471 59637490 0.85
# Only 4-cycle	 12535287 10253679 0.82
# Only Diamond	 1421411 1206502 0.85
# Only 4-clique	 14677 13147 0.90
# Wedge+edge	 490252190 394350338 0.80
# Triangle+edge	 4409561 3455298 0.78
# 4-star		 5739258 4854252 0.85
# Prong		 39310085 31801144 0.81
# 4-path		 27466740 21528660 0.78
# Forktailed-tri	 973114 802787 0.82
# Lontailed-tri	 1080752 837939 0.78
# Doubletailed-tri 1578024 1276287 0.81
# Tailed-4-cycle	 1099659 851976 0.77
# 5-cycle		 153525 114916 0.75
# Hourglass	 13742 10640 0.77
# Cobra		 65384 52151 0.80
# Stingray	 80564 65987 0.82
# Hatted-4-cycle	 44375 33293 0.75
# 3-wedge-col	 7446 5596 0.75
# 3-tri-collision	 696 569 0.82
# Tailed-4-clique	 1661 1407 0.85
# Triangle-strip	 3466 2762 0.80
# Diamond-wed-col	 1387 1064 0.77
# 4-wheel		 55 43 0.78
# Hatted-4-clique	 139 115 0.83
# Almost-5-clique	 4 4 1.00
# 5-clique	 0 0 -
#
# Random Graph File r6 Raw Output:
#  Running command: ./escape/exe/count_five ./datasets/email-univ_random/email-univ_r6.mtx
# Loading graph
# Converting to CSR
# Relabeling graph
# Creating DAG
# Counting 3-vertex
# Counting 4-vertex
# Getting easy four vertex patterns
# Getting four cycles
# Getting four cliques
# Counting 5-vertex
# Getting all triangles
# Also getting reverse triangle info
# Counting trees
# Counting triangle based patterns
# Counting 4-cycle and 4-clique based patterns
# Counting five cycles
# Counting collision patterns
# Counting almost cliques
# ==============
# Basic size
# ==============
# Vertices	 1133
# Edges		 5365
# ==============
# 3 vertex patterns
# ==============
# Ind set		 241761806 235786994 0.98
# Only edge	 6066118 5884324 0.97
# Wedge		 92127 89667 0.97
# Triangle	 820 820 1.00
# ==============
# 4 vertex patterns
# ==============
# Ind set		 68297710195 64985569570 0.95
# Only edge	 3427356952 3200032460 0.93
# Matching	 14288757 12797625 0.90
# Only wedge	 104103510 96269021 0.92
# Only triangle	 926600 869495 0.94
# 3-star		 748664 691559 0.92
# 3-path		 1569584 1414932 0.90
# Tailed triangle	 59375 54871 0.92
# 4-cycle		 10678 9552 0.89
# Diamond		 1153 1099 0.95
# 4-clique	 9 9 1.00
# ==============
# 5 vertex patterns
# ==============
# Ind set		 15421622962031 14203211763473 0.92
# Only edge	 1289828666457 1150332152888 0.89
# Matching	 16132007076 13625928710 0.84
# Only wedge	 58766431395 51252015373 0.87
# Only triangle	 523065700 457268335 0.87
# Only 3-star	 845241656 728049712 0.86
# Only 3-path	 1772060336 1488348450 0.84
# Only Tailed tri	 67034375 57092182 0.85
# Only 4-cycle	 12055462 9934914 0.82
# Only Diamond	 1301737 1132806 0.87
# Only 4-clique	 10161 9108 0.90
# Wedge+edge	 488551290 395174564 0.81
# Triangle+edge	 4336235 3446566 0.79
# 4-star		 5672352 4857289 0.86
# Prong		 37824013 30930948 0.82
# 4-path		 26603331 21101394 0.79
# Forktailed-tri	 890186 744334 0.84
# Lontailed-tri	 995919 790913 0.79
# Doubletailed-tri 1413081 1157382 0.82
# Tailed-4-cycle	 1015319 803341 0.79
# 5-cycle		 143429 110136 0.77
# Hourglass	 11494 9204 0.80
# Cobra		 53540 43940 0.82
# Stingray	 68216 57324 0.84
# Hatted-4-cycle	 37593 29291 0.78
# 3-wedge-col	 6451 4995 0.77
# 3-tri-collision	 565 486 0.86
# Tailed-4-clique	 1132 974 0.86
# Triangle-strip	 2518 2062 0.82
# Diamond-wed-col	 1040 821 0.79
# 4-wheel		 35 35 1.00
# Hatted-4-clique	 79 79 1.00
# Almost-5-clique	 0 0 -
# 5-clique	 0 0 -
#
# Random Graph File r7 Raw Output:
#  Running command: ./escape/exe/count_five ./datasets/email-univ_random/email-univ_r7.mtx
# Loading graph
# Converting to CSR
# Relabeling graph
# Creating DAG
# Counting 3-vertex
# Counting 4-vertex
# Getting easy four vertex patterns
# Getting four cycles
# Getting four cliques
# Counting 5-vertex
# Getting all triangles
# Also getting reverse triangle info
# Counting trees
# Counting triangle based patterns
# Counting 4-cycle and 4-clique based patterns
# Counting five cycles
# Counting collision patterns
# Counting almost cliques
# ==============
# Basic size
# ==============
# Vertices	 1133
# Edges		 5360
# ==============
# 3 vertex patterns
# ==============
# Ind set		 241761806 235792291 0.98
# Only edge	 6060463 5879381 0.97
# Wedge		 91765 89317 0.97
# Triangle	 816 816 1.00
# ==============
# 4 vertex patterns
# ==============
# Ind set		 68297710195 64988349109 0.95
# Only edge	 3424161877 3197649255 0.93
# Matching	 14262316 12781220 0.90
# Only wedge	 103694450 95907566 0.92
# Only triangle	 922080 865527 0.94
# 3-star		 743433 686880 0.92
# 3-path		 1558576 1405804 0.90
# Tailed triangle	 58755 54379 0.93
# 4-cycle		 10467 9373 0.90
# Diamond		 1115 1073 0.96
# 4-clique	 7 7 1.00
# ==============
# 5 vertex patterns
# ==============
# Ind set		 15421622962031 14204175253525 0.92
# Only edge	 1288626253232 1149587076986 0.89
# Matching	 16102155751 13611044819 0.85
# Only wedge	 58535517025 51067727758 0.87
# Only triangle	 520514160 455341367 0.87
# Only 3-star	 839335857 723181188 0.86
# Only 3-path	 1759632304 1478811567 0.84
# Only Tailed tri	 66334395 56574382 0.85
# Only 4-cycle	 11817243 9739941 0.82
# Only Diamond	 1258835 1104086 0.88
# Only 4-clique	 7903 7161 0.91
# Wedge+edge	 486189323 393467362 0.81
# Triangle+edge	 4311333 3428117 0.80
# 4-star		 5615126 4813936 0.86
# Prong		 37560453 30723197 0.82
# 4-path		 26406480 20940491 0.79
# Forktailed-tri	 874584 731810 0.84
# Lontailed-tri	 988581 784944 0.79
# Doubletailed-tri 1408020 1155636 0.82
# Tailed-4-cycle	 1006216 796464 0.79
# 5-cycle		 142461 109295 0.77
# Hourglass	 11303 9037 0.80
# Cobra		 52761 44182 0.84
# Stingray	 66238 56459 0.85
# Hatted-4-cycle	 37360 29186 0.78
# 3-wedge-col	 6360 4946 0.78
# 3-tri-collision	 530 478 0.90
# Tailed-4-clique	 795 691 0.87
# Triangle-strip	 2428 2110 0.87
# Diamond-wed-col	 993 831 0.84
# 4-wheel		 29 26 0.90
# Hatted-4-clique	 55 49 0.89
# Almost-5-clique	 1 1 1.00
# 5-clique	 0 0 -
#
# Random Graph File r8 Raw Output:
#  Running command: ./escape/exe/count_five ./datasets/email-univ_random/email-univ_r8.mtx
# Loading graph
# Converting to CSR
# Relabeling graph
# Creating DAG
# Counting 3-vertex
# Counting 4-vertex
# Getting easy four vertex patterns
# Getting four cycles
# Getting four cliques
# Counting 5-vertex
# Getting all triangles
# Also getting reverse triangle info
# Counting trees
# Counting triangle based patterns
# Counting 4-cycle and 4-clique based patterns
# Counting five cycles
# Counting collision patterns
# Counting almost cliques
# ==============
# Basic size
# ==============
# Vertices	 1133
# Edges		 5383
# ==============
# 3 vertex patterns
# ==============
# Ind set		 241761806 235767142 0.98
# Only edge	 6086476 5903689 0.97
# Wedge		 92652 90135 0.97
# Triangle	 839 839 1.00
# ==============
# 4 vertex patterns
# ==============
# Ind set		 68297710195 64974717362 0.95
# Only edge	 3438859222 3210272055 0.93
# Matching	 14384928 12881926 0.90
# Only wedge	 104696760 96761814 0.92
# Only triangle	 948070 889113 0.94
# 3-star		 754605 695648 0.92
# 3-path		 1583426 1424790 0.90
# Tailed triangle	 61195 56771 0.93
# 4-cycle		 10740 9634 0.90
# Diamond		 1145 1067 0.93
# 4-clique	 13 13 1.00
# ==============
# 5 vertex patterns
# ==============
# Ind set		 15421622962031 14199290798283 0.92
# Only edge	 1294157354067 1153878119140 0.89
# Matching	 16240584135 13714382594 0.84
# Only wedge	 59101321020 51508738074 0.87
# Only triangle	 535185515 467306863 0.87
# Only 3-star	 851949045 732047762 0.86
# Only 3-path	 1787687954 1498190112 0.84
# Only Tailed tri	 69089155 59021157 0.85
# Only 4-cycle	 12125460 10008908 0.83
# Only Diamond	 1292705 1097258 0.85
# Only 4-clique	 14677 13218 0.90
# Wedge+edge	 492988250 398330317 0.81
# Triangle+edge	 4451366 3531184 0.79
# 4-star		 5725730 4887151 0.85
# Prong		 38513286 31366671 0.81
# 4-path		 26902313 21230478 0.79
# Forktailed-tri	 913688 768031 0.84
# Lontailed-tri	 1030135 817899 0.79
# Doubletailed-tri 1484057 1225624 0.83
# Tailed-4-cycle	 1036038 819901 0.79
# 5-cycle		 144565 109844 0.76
# Hourglass	 11937 9717 0.81
# Cobra		 55261 44671 0.81
# Stingray	 67940 56474 0.83
# Hatted-4-cycle	 38843 30857 0.79
# 3-wedge-col	 6492 5164 0.80
# 3-tri-collision	 489 395 0.81
# Tailed-4-clique	 1554 1366 0.88
# Triangle-strip	 2446 2000 0.82
# Diamond-wed-col	 970 806 0.83
# 4-wheel		 19 16 0.84
# Hatted-4-clique	 97 91 0.94
# Almost-5-clique	 1 1 1.00
# 5-clique	 0 0 -
#
# Random Graph File r9 Raw Output:
#  Running command: ./escape/exe/count_five ./datasets/email-univ_random/email-univ_r9.mtx
# Loading graph
# Converting to CSR
# Relabeling graph
# Creating DAG
# Counting 3-vertex
# Counting 4-vertex
# Getting easy four vertex patterns
# Getting four cycles
# Getting four cliques
# Counting 5-vertex
# Getting all triangles
# Also getting reverse triangle info
# Counting trees
# Counting triangle based patterns
# Counting 4-cycle and 4-clique based patterns
# Counting five cycles
# Counting collision patterns
# Counting almost cliques
# ==============
# Basic size
# ==============
# Vertices	 1133
# Edges		 5353
# ==============
# 3 vertex patterns
# ==============
# Ind set		 241761806 235799735 0.98
# Only edge	 6052546 5872398 0.97
# Wedge		 91280 88868 0.97
# Triangle	 804 804 1.00
# ==============
# 4 vertex patterns
# ==============
# Ind set		 68297710195 64992286585 0.95
# Only edge	 3419688772 3194200750 0.93
# Matching	 14225320 12767998 0.90
# Only wedge	 103146400 95475776 0.93
# Only triangle	 908520 854356 0.94
# 3-star		 731658 677494 0.93
# 3-path		 1531672 1385034 0.90
# Tailed triangle	 56246 52122 0.93
# 4-cycle		 10098 9067 0.90
# Diamond		 1061 1001 0.94
# 4-clique	 10 10 1.00
# ==============
# 5 vertex patterns
# ==============
# Ind set		 15421622962031 14205556740350 0.92
# Only edge	 1286942874717 1148463122781 0.89
# Matching	 16060386703 13598253591 0.85
# Only wedge	 58226142800 50862768363 0.87
# Only triangle	 512859540 450255547 0.88
# Only 3-star	 826041882 714182364 0.86
# Only 3-path	 1729257688 1458169837 0.84
# Only Tailed tri	 63501734 54346958 0.86
# Only 4-cycle	 11400642 9438503 0.83
# Only Diamond	 1197869 1034046 0.86
# Only 4-clique	 11290 10215 0.90
# Wedge+edge	 483041630 392684728 0.81
# Triangle+edge	 4243948 3405360 0.80
# 4-star		 5391796 4657408 0.86
# Prong		 36313259 29917188 0.82
# 4-path		 25636181 20474430 0.80
# Forktailed-tri	 799857 672971 0.84
# Lontailed-tri	 935392 748599 0.80
# Doubletailed-tri 1314466 1085216 0.83
# Tailed-4-cycle	 947449 756109 0.80
# 5-cycle		 134233 103765 0.77
# Hourglass	 10053 8009 0.80
# Cobra		 49577 40606 0.82
# Stingray	 59668 49547 0.83
# Hatted-4-cycle	 34312 26908 0.78
# 3-wedge-col	 5841 4544 0.78
# 3-tri-collision	 511 428 0.84
# Tailed-4-clique	 1161 995 0.86
# Triangle-strip	 2278 1828 0.80
# Diamond-wed-col	 934 733 0.78
# 4-wheel		 34 25 0.74
# Hatted-4-clique	 92 74 0.80
# Almost-5-clique	 3 3 1.00
# 5-clique	 0 0 -
#
# Random Graph File r10 Raw Output:
#  Running command: ./escape/exe/count_five ./datasets/email-univ_random/email-univ_r10.mtx
# Loading graph
# Converting to CSR
# Relabeling graph
# Creating DAG
# Counting 3-vertex
# Counting 4-vertex
# Getting easy four vertex patterns
# Getting four cycles
# Getting four cliques
# Counting 5-vertex
# Getting all triangles
# Also getting reverse triangle info
# Counting trees
# Counting triangle based patterns
# Counting 4-cycle and 4-clique based patterns
# Counting five cycles
# Counting collision patterns
# Counting almost cliques
# ==============
# Basic size
# ==============
# Vertices	 1133
# Edges		 5349
# ==============
# 3 vertex patterns
# ==============
# Ind set		 241761806 235804367 0.98
# Only edge	 6048022 5867708 0.97
# Wedge		 91438 88876 0.97
# Triangle	 854 854 1.00
# ==============
# 4 vertex patterns
# ==============
# Ind set		 68297710195 64994907094 0.95
# Only edge	 3417132712 3191602583 0.93
# Matching	 14203766 12720958 0.90
# Only wedge	 103324940 95419377 0.92
# Only triangle	 965020 905720 0.94
# 3-star		 741651 682351 0.92
# 3-path		 1563515 1404267 0.90
# Tailed triangle	 61488 57156 0.93
# 4-cycle		 10709 9626 0.90
# Diamond		 1116 1050 0.94
# 4-clique	 11 11 1.00
# ==============
# 5 vertex patterns
# ==============
# Ind set		 15421622962031 14206524850763 0.92
# Only edge	 1285980944137 1147550361204 0.89
# Matching	 16036052237 13549997475 0.84
# Only wedge	 58326928630 50802409023 0.87
# Only triangle	 544753790 476437833 0.87
# Only 3-star	 837323979 717938517 0.86
# Only 3-path	 1765208435 1476645376 0.84
# Only Tailed tri	 69419952 59460915 0.86
# Only 4-cycle	 12090461 9997505 0.83
# Only Diamond	 1259964 1081348 0.86
# Only 4-clique	 12419 11152 0.90
# Wedge+edge	 483427284 389738827 0.81
# Triangle+edge	 4502715 3569199 0.79
# 4-star		 5636903 4786345 0.85
# Prong		 37975552 30840665 0.81
# 4-path		 26619325 20937326 0.79
# Forktailed-tri	 924443 780834 0.84
# Lontailed-tri	 1042724 831537 0.80
# Doubletailed-tri 1455069 1203967 0.83
# Tailed-4-cycle	 1034951 821496 0.79
# 5-cycle		 146255 111125 0.76
# Hourglass	 12513 10416 0.83
# Cobra		 52642 42873 0.81
# Stingray	 65732 55337 0.84
# Hatted-4-cycle	 39141 31399 0.80
# 3-wedge-col	 6535 5248 0.80
# 3-tri-collision	 443 360 0.81
# Tailed-4-clique	 1353 1187 0.88
# Triangle-strip	 2329 1883 0.81
# Diamond-wed-col	 990 793 0.80
# 4-wheel		 33 24 0.73
# Hatted-4-clique	 92 74 0.80
# Almost-5-clique	 3 3 1.00
# 5-clique	 0 0 -
#
# Random Graphs Results (Averaged):
# {
#     "4-1" : 11.60,
#     "4-2" : 1086.80,
#     "4-3" : 55552.30,
#     "4-4" : 9609.70,
#     "4-5" : 686822.60,
#     "4-6" : 1413371.10,
#     "5-1" : 4789555.90,
#     "5-10" : 45169.70,
#     "5-11" : 57478.60,
#     "5-12" : 30721.40,
#     "5-13" : 5187.10,
#     "5-14" : 458.00,
#     "5-15" : 1209.80,
#     "5-16" : 2150.90,
#     "5-17" : 863.80,
#     "5-18" : 30.80,
#     "5-19" : 90.50,
#     "5-2" : 30938883.80,
#     "5-20" : 3.00,
#     "5-3" : 21085923.50,
#     "5-4" : 752270.90,
#     "5-5" : 804039.20,
#     "5-6" : 1189394.20,
#     "5-7" : 815835.20,
#     "5-8" : 110728.10,
#     "5-9" : 9606.00,
# }

# %%
def convert_mtx_to_edges(mtx_file_path, edges_file_path):
    with open(mtx_file_path, 'r') as mtx_file:
        lines = mtx_file.readlines()
    
    # Extract number of nodes and edges
    node_edge_info = lines[1].strip().split()
    node_count = int(node_edge_info[0])
    edge_count = int(node_edge_info[2])

    edges = []
    for line in lines[2:]:
        if line.strip():  # Skip empty lines
            nodes = list(map(int, line.strip().split()))
            if len(nodes) == 2:
                nodes = [node - 1 for node in nodes]
                nodes.sort()
                edges.append(nodes)

    # Write to .edges file
    with open(edges_file_path, 'w') as edges_file:
        edges_file.write(f"{node_count} {edge_count}\n")
        for edge in edges:
            edges_file.write(f"{edge[0]} {edge[1]}\n")

# Perform the conversion
mtx_file_path = './datasets/soc-pages-food.mtx'
edges_file_path = './datasets/soc-pages-food.edges'

convert_mtx_to_edges(mtx_file_path, edges_file_path)

# Output the transformed file content for verification
with open(edges_file_path, 'r') as edges_file:
    transformed_lines = edges_file.readlines()

transformed_lines[:10]
# Out:
# ['620 2102\n',
#  '0 276\n',
#  '0 58\n',
#  '0 132\n',
#  '0 603\n',
#  '0 398\n',
#  '0 555\n',
#  '1 265\n',
#  '1 611\n',
#  '2 265\n']
